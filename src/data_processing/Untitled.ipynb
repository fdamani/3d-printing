# %%
import gcode_to_train as gctt
import numpy as np
import matplotlib.pyplot as plt

# %%
#filename = "../../data/gcode/Windlicht01.gcode"
#filename = "../../data/gcode/dino_body_sliced_fill_density_90.gcode"
filename = "../../data/gcode/hans_solo_blaster_fill_density_90.gcode"
x, x_raw = gctt.run(filename)

# %%
x.shape
# Out:
# (634542, 6)

# %%
plt.figure(figsize=(20,4))
plt.plot(x[2:175,1])

# %%
plt.figure(figsize=(20,4))
plt.plot(x[1000:2000,1])

# %%
plt.figure(figsize=(20,4))
plt.plot(x[5:1000,1])

# %%
x.shape
# Out:
# (326850, 6)

# %%
plt.figure(figsize=(20,4))
plt.plot(x[450:750,1])

# %%
plt.figure(figsize=(20,4))
plt.plot(x[0:100,5])

# %%
plt.scatter(x[1000:2000, 1],x[1000:2000, 2])

# %%
plt.scatter(x[500:750, 1],x[500:750, 2])

# %%
x[0:100,5]
# Out:
# array([0.        , 1.        , 1.        , 0.13888889, 0.16666667,
#        0.16666667, 0.16666667, 0.16666667, 0.16666667, 0.16666667,
#        0.16666667, 0.16666667, 0.16666667, 0.16666667, 0.16666667,
#        0.16666667, 0.16666667, 0.16666667, 0.16666667, 0.16666667,
#        0.16666667, 0.16666667, 0.16666667, 0.16666667, 0.16666667,
#        0.16666667, 0.16666667, 0.16666667, 0.16666667, 0.16666667,
#        0.16666667, 0.16666667, 0.16666667, 0.16666667, 0.16666667,
#        0.16666667, 0.16666667, 0.16666667, 0.16666667, 0.16666667,
#        0.16666667, 0.16666667, 1.        , 0.16666667, 0.16666667,
#        0.16666667, 0.16666667, 0.16666667, 0.16666667, 0.16666667,
#        0.16666667, 0.16666667, 0.16666667, 0.16666667, 0.16666667,
#        0.16666667, 0.16666667, 0.16666667, 0.16666667, 0.16666667,
#        0.16666667, 0.16666667, 0.16666667, 0.16666667, 0.16666667,
#        0.16666667, 0.16666667, 0.16666667, 0.16666667, 0.16666667,
# ...

# %%
plt.figure(figsize=(20,4))
plt.plot(x_raw[0:100,5])

# %%
np.median(x_raw[:,5])
# Out:
# 3491.506

# %%
np.median(x[:,5])
# Out:
# 0.3232875925925926
