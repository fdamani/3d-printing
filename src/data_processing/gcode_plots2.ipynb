# %%
import gcode_to_train as gctt
import numpy as np
import matplotlib.pyplot as plt

# %%
#filename = "../../data/gcode/dino_body_sliced.gcode"
#filename = "../../data/gcode/dino_body_sliced_fill_density_ten.gcode"
filename = "../../data/gcode/hans_solo_blaster_fill_density_90.gcode"

x, x_raw = gctt.run(filename)

# %% [markdown]
# ## plots of normalized x position vs time

# %%
plt.figure(figsize=(20,4))
plt.plot(x[2:175,1])

# %%
plt.figure(figsize=(20,4))
plt.plot(x[2:500,1])

# %%
plt.figure(figsize=(20,4))
plt.plot(x[1000:2000, 1])

# %%
plt.figure(figsize=(20,4))
plt.plot(x[1500:3000,1])

# %%
plt.figure(figsize=(20,4))
plt.plot(x[10000:20000,1])

# %%
x.shape
# Out:
# (326850, 6)

# %% [markdown]
# ## plots of normalized y position vs time

# %%
plt.figure(figsize=(20,4))
plt.plot(x[2:175,2])

# %%
plt.figure(figsize=(20,4))
plt.plot(x[2:500,2])

# %%
plt.figure(figsize=(20,4))
plt.plot(x[2:2000,2])

# %%
plt.figure(figsize=(20,4))
plt.plot(x[2:5000,2])

# %%
plt.figure(figsize=(20,4))
plt.plot(x[2:10000,2])

# %%
plt.figure(figsize=(20,4))
plt.plot(x[2:,2])

# %% [markdown]
# ## z axis

# %%
plt.figure(figsize=(20,4))
plt.plot(x[0:,3])

# %% [markdown]
# ## E axis (filament spool position)

# %%
plt.figure(figsize=(20,4))
plt.plot(x[0:500,4])

# %%
plt.figure(figsize=(20,4))
plt.plot(x[0:2000,4])

# %%
plt.figure(figsize=(20,4))
plt.plot(x[0:10000,4])

# %%
plt.figure(figsize=(20,4))
plt.plot(x[:,4])

# %% [markdown]
# ## F axis (printer speed)

# %%
plt.figure(figsize=(20,4))
plt.plot(x[0:100,5])

# %%
plt.figure(figsize=(20,4))
plt.plot(x_raw[0:1000,5])
