# %%
import numpy as np

# %%
filename = "../data/gcode/dino_body_sliced_perimeter_speed_120.gcode"
f = open(filename)

# %%
x = f.readlines()

# %%
# find simplest way of starting linear commands. third g92 or line number is fine.
# Out:
# ['; generated by Slic3r 1.2.9 on 2018-04-27 at 17:21:04\n',
#  '\n',
#  '; external perimeters extrusion width = 0.35mm\n',
#  '; perimeters extrusion width = 0.33mm\n',
#  '; infill extrusion width = 0.50mm\n',
#  '; solid infill extrusion width = 0.38mm\n',
#  '; top infill extrusion width = 0.22mm\n',
#  '\n',
#  'M107\n',
#  ';This profile is designed specifically for LulzBot TAZ 6 3D Printer\n',
#  ';Basic slice data:\n',
#  ';Sliced at: {day} {date} {time}\n',
#  ';Layer height: {layer_height}\n',
#  ';Walls: {wall_thickness}\n',
#  ';Fill: {fill_density}\n',
#  ';Estimated Print time: {print_time}\n',
#  ';Filament used: {filament_amount}m {filament_weight}g\n',
#  ';Filament cost: {filament_cost}\n',
#  ';Variables to replace: print_bed_temperature, print_temperature, clean_temperature\n',
#  "G26                          ; clear potential 'probe fail' condition\n",
#  'G21                          ; set units to Millimeters\n',
# ...

# %%
x = f.readline().split("\n")

# %%
x[0]
# Out:
# 'G1 X-15 Y100 F3000           ; move above wiper pad'

# %%
str.startswith(x[0], "G1")
# Out:
# True

# %%
filename = "../data/gcode/dino_body_sliced_perimeter_speed_120.gcode"
f = open(filename)
counter = 0
for line in f:
    command = line.split("\n")
    if str.startswith(command[0], "G92"):
        counter = counter + 1
        if counter == 3: # start of linear gcode commands
    
    
    if command[0][0] == 'G':
# Out:
#   File "<ipython-input-37-32e57511eb03>", line 7
#     f = open("../data/gcode/dino_body_sliced_perimeter_speed_120.gcode")
#     ^
# IndentationError: expected an indented block

# %% [markdown]
# create a dataset
#
# G1/G92 X Y Z E F

# %%
raw_data
# Out:
# ['; generated by Slic3r 1.2.9 on 2018-04-27 at 17:21:04\n',
#  '\n',
#  '; external perimeters extrusion width = 0.35mm\n',
#  '; perimeters extrusion width = 0.33mm\n',
#  '; infill extrusion width = 0.50mm\n',
#  '; solid infill extrusion width = 0.38mm\n',
#  '; top infill extrusion width = 0.22mm\n',
#  '\n',
#  'M107\n',
#  ';This profile is designed specifically for LulzBot TAZ 6 3D Printer\n',
#  ';Basic slice data:\n',
#  ';Sliced at: {day} {date} {time}\n',
#  ';Layer height: {layer_height}\n',
#  ';Walls: {wall_thickness}\n',
#  ';Fill: {fill_density}\n',
#  ';Estimated Print time: {print_time}\n',
#  ';Filament used: {filament_amount}m {filament_weight}g\n',
#  ';Filament cost: {filament_cost}\n',
#  ';Variables to replace: print_bed_temperature, print_temperature, clean_temperature\n',
#  "G26                          ; clear potential 'probe fail' condition\n",
#  'G21                          ; set units to Millimeters\n',
# ...
